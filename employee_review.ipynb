# %%
# dependencies
import os
import pandas as pd

# %%
# load csv data file
employeereview="/Users/wheat/ETL_Group_Project/employee_reviews.csv"
employeereview_df = pd.read_csv(employeereview)
employeereview_df.head()
# Out:
#    Unnamed: 0 company           location          dates  \
# 0           1  google               none   Dec 11, 2018
# 1           2  google  Mountain View, CA   Jun 21, 2013
# 2           3  google       New York, NY   May 10, 2014
# 3           4  google  Mountain View, CA    Feb 8, 2015
# 4           5  google    Los Angeles, CA   Jul 19, 2018
#
#                                   job-title  \
# 0     Current Employee - Anonymous Employee
# 1         Former Employee - Program Manager
# 2  Current Employee - Software Engineer III
# 3     Current Employee - Anonymous Employee
# 4       Former Employee - Software Engineer
#
#                                              summary  \
# 0                           Best Company to work for
# 1  Moving at the speed of light, burn out is inev...
# 2  Great balance between big-company security and...
# 3  The best place I've worked and also the most d...
# 4                    Unique, one of a kind dream job
#
# ...

# %%
# pull all needed columns
new_employee_df = employeereview_df[['company', 'location', 'job-title','overall-ratings','work-balance-stars','culture-values-stars','carrer-opportunities-stars','comp-benefit-stars','senior-mangemnet-stars','helpful-count']].copy()
new_employee_df
# Out:
#          company           location  \
# 0         google               none
# 1         google  Mountain View, CA
# 2         google       New York, NY
# 3         google  Mountain View, CA
# 4         google    Los Angeles, CA
# 5         google  Mountain View, CA
# 6         google       New York, NY
# 7         google               none
# 8         google       New York, NY
# 9         google               none
# 10        google  Mountain View, CA
# 11        google               none
# 12        google               none
# 13        google  San Francisco, CA
# 14        google               none
# 15        google               none
# 16        google               none
# 17        google               none
# 18        google               none
# 19        google               none
# 20        google       New York, NY
# 21        google               none
# 22        google               none
# 23        google               none
# 24        google    Los Angeles, CA
# ...

# %%
# Filter data based on location to only San Francisco, CA
SanFran_df=new_employee_df.loc[new_employee_df['location'] == 'San Francisco, CA']
SanFran_df
# Out:
#          company           location  \
# 13        google  San Francisco, CA
# 27        google  San Francisco, CA
# 68        google  San Francisco, CA
# 91        google  San Francisco, CA
# 103       google  San Francisco, CA
# 201       google  San Francisco, CA
# 223       google  San Francisco, CA
# 251       google  San Francisco, CA
# 272       google  San Francisco, CA
# 296       google  San Francisco, CA
# 386       google  San Francisco, CA
# 404       google  San Francisco, CA
# 407       google  San Francisco, CA
# 447       google  San Francisco, CA
# 466       google  San Francisco, CA
# 467       google  San Francisco, CA
# 515       google  San Francisco, CA
# 529       google  San Francisco, CA
# 540       google  San Francisco, CA
# 606       google  San Francisco, CA
# 616       google  San Francisco, CA
# 622       google  San Francisco, CA
# 629       google  San Francisco, CA
# 643       google  San Francisco, CA
# 657       google  San Francisco, CA
# ...

# %%
print(SanFran_df.['job-title'].str.replace('Current Employee - ', '')
# Out:
#   File "<ipython-input-13-75b7a4a153e8>", line 1
#     print(SanFran_df.['job-title'].str.replace('Current Employee - ', '')
#                      ^
# SyntaxError: invalid syntax
